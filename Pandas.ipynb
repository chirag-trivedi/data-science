# %%
import pandas as pd
import numpy as np

# %%
med_price_list = [55,25,75,40,90]
med_price_arr = np.array(med_price_list)

series_list = pd.Series(med_price_list)
series_arr = pd.Series(med_price_arr)

print(series_list)
print(series_arr)
# Out:
# 0    55
# 1    25
# 2    75
# 3    40
# 4    90
# dtype: int64
# 0    55
# 1    25
# 2    75
# 3    40
# 4    90
# dtype: int64

# %%
med_price_list_labeled = pd.Series(med_price_list, index=["Omeprazole","Advil","Tylenol","Metformin","Cetrizine"])
print(med_price_list_labeled)
# Out:
# Omeprazole    55
# Advil         25
# Tylenol       75
# Metformin     40
# Cetrizine     90
# dtype: int64

# %%
med_price_list_labeled_updated = med_price_list_labeled + 2.5
print(med_price_list_labeled_updated)
# Out:
# Omeprazole    57.5
# Advil         27.5
# Tylenol       77.5
# Metformin     42.5
# Cetrizine     92.5
# dtype: float64

# %%
new_price_list = [77, 45.5, 100, 50, 80]
new_price_list_labeled = pd.Series(new_price_list, index = ['Omeprazole','Azithromycin','Metformin','Ibuprofen','Cetirizine'])
print(new_price_list_labeled)
# Out:
# Omeprazole       77.0
# Azithromycin     45.5
# Metformin       100.0
# Ibuprofen        50.0
# Cetirizine       80.0
# dtype: float64

# %%
print('Difference between new price and old price - ')
print(new_price_list_labeled - med_price_list_labeled_updated)
# Out:
# Difference between new price and old price -
# Advil            NaN
# Azithromycin     NaN
# Cetirizine       NaN
# Cetrizine        NaN
# Ibuprofen        NaN
# Metformin       57.5
# Omeprazole      19.5
# Tylenol          NaN
# dtype: float64

# %% [markdown]
# Pandas DataFrame

# %%
student = ['Mary', 'Peter', 'Susan', 'Toby', 'Vishal']
df1 = pd.DataFrame(student,columns=['Student'])
print(df1)
# Out:
#   Student
# 0    Mary
# 1   Peter
# 2   Susan
# 3    Toby
# 4  Vishal

# %% [markdown]
# Pandas DataFrame using a Dict

# %%
grades = ['A+','B-','A','A','A+']
df2 = pd.DataFrame({'Student':student,'Grade':grades})
print(df2)
# Out:
#   Student Grade
# 0    Mary    A+
# 1   Peter    B-
# 2   Susan     A
# 3    Toby     A
# 4  Vishal    A+

# %% [markdown]
# Data Frame using random vals

# %%
df4 = pd.DataFrame(np.random.randn(5,2),columns=["A","B"])
print(df4)
# Out:
#           A         B
# 0  1.011823 -1.074333
# 1  0.014171  0.439865
# 2 -0.543226 -0.792859
# 3  0.663806 -0.146705
# 4  0.687773 -0.911408

# %% [markdown]
# Pandas Access and Modify

# %%
operators = ['AT&T', 'Verizon', 'T-Mobile US', 'US Cellular']
revenue = [171.76, 128.29, 68.4, 4.04]
telecom = pd.Series(revenue, index=operators)
print(telecom)
# Out:
# AT&T           171.76
# Verizon        128.29
# T-Mobile US     68.40
# US Cellular      4.04
# dtype: float64

# %%
telecom['Verizon']
# Out:
# 128.29

# %%
telecom[:3]
# Out:
# AT&T           171.76
# Verizon        128.29
# T-Mobile US     68.40
# dtype: float64

# %%
telecom[[0,2,3]]
# Out:
# <ipython-input-50-f444878ab99e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   telecom[[0,2,3]]
# AT&T           171.76
# T-Mobile US     68.40
# US Cellular      4.04
# dtype: float64

# %%
telecom[:'US Cellular']
# Out:
# AT&T           171.76
# Verizon        128.29
# T-Mobile US     68.40
# US Cellular      4.04
# dtype: float64

# %% [markdown]
# Access Data Frame

# %%
store_data = pd.DataFrame({'CustomerID': ['CustID00','CustID01','CustID02','CustID03','CustID04']
                           ,'location': ['Chicago', 'Boston', 'Seattle', 'San Francisco', 'Austin']
                           ,'gender': ['M','M','F','M','F']
                           ,'type': ['Electronics','Food&Beverages','Food&Beverages','Medicine','Beauty']
                           ,'quantity':[1,3,4,2,1],'total_bill':[100,75,125,50,80]})
store_data
# Out:
#   CustomerID       location gender            type  quantity  total_bill
# 0   CustID00        Chicago      M     Electronics         1         100
# 1   CustID01         Boston      M  Food&Beverages         3          75
# 2   CustID02        Seattle      F  Food&Beverages         4         125
# 3   CustID03  San Francisco      M        Medicine         2          50
# 4   CustID04         Austin      F          Beauty         1          80

# %%
store_data[:1]
# Out:
#   CustomerID location gender         type  quantity  total_bill
# 0   CustID00  Chicago      M  Electronics         1         100

# %%
store_data['location']
# Out:
# 0          Chicago
# 1           Boston
# 2          Seattle
# 3    San Francisco
# 4           Austin
# Name: location, dtype: object

# %%
store_data.loc[0:2]
# Out:
#   CustomerID location gender            type  quantity  total_bill
# 0   CustID00  Chicago      M     Electronics         1         100
# 1   CustID01   Boston      M  Food&Beverages         3          75
# 2   CustID02  Seattle      F  Food&Beverages         4         125

# %%
store_data.loc[[1,4],['location','total_bill']]
# Out:
#   location  total_bill
# 1   Boston          75
# 4   Austin          80

# %%
store_data.iloc[0:2,0:2]
# Out:
#   CustomerID location
# 0   CustID00  Chicago
# 1   CustID01   Boston

# %%
store_data.loc[4,'type'] = 'Electronix'
store_data
# Out:
#   CustomerID       location gender            type  quantity  total_bill
# 0   CustID00        Chicago      M     Electronics         1         100
# 1   CustID01         Boston      M  Food&Beverages         3          75
# 2   CustID02        Seattle      F  Food&Beverages         4         125
# 3   CustID03  San Francisco      M        Medicine         2          50
# 4   CustID04         Austin      F      Electronix         1          80

# %%
store_data['quantity']> 1
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: quantity, dtype: bool

# %%
store_data[store_data['quantity']>1]
# Out:
#   CustomerID       location gender            type  quantity  total_bill
# 1   CustID01         Boston      M  Food&Beverages         3          75
# 2   CustID02        Seattle      F  Food&Beverages         4         125
# 3   CustID03  San Francisco      M        Medicine         2          50

# %%
store_data['rating'] = [2,4,1,3,1]
store_data
# Out:
#   CustomerID       location gender            type  quantity  total_bill  \
# 0   CustID00        Chicago      M     Electronics         1         100
# 1   CustID01         Boston      M  Food&Beverages         3          75
# 2   CustID02        Seattle      F  Food&Beverages         4         125
# 3   CustID03  San Francisco      M        Medicine         2          50
# 4   CustID04         Austin      F      Electronix         1          80
#
#    rating
# 0       2
# 1       4
# 2       1
# 3       3
# 4       1

# %%
store_data.drop('CustomerID',axis=1,inplace=True)
store_data
# Out:
#         location gender            type  quantity  total_bill  rating
# 0        Chicago      M     Electronics         1         100       2
# 1         Boston      M  Food&Beverages         3          75       4
# 2        Seattle      F  Food&Beverages         4         125       1
# 3  San Francisco      M        Medicine         2          50       3
# 4         Austin      F      Electronix         1          80       1

# %%
new_store_data = store_data.copy()
new_store_data
# Out:
#         location gender            type  quantity  total_bill  rating
# 0        Chicago      M     Electronics         1         100       2
# 1         Boston      M  Food&Beverages         3          75       4
# 2        Seattle      F  Food&Beverages         4         125       1
# 3  San Francisco      M        Medicine         2          50       3
# 4         Austin      F      Electronix         1          80       1

# %%
new_store_data.drop(['location','rating'],axis=1,inplace=True)
new_store_data
# Out:
#   gender            type  quantity  total_bill
# 0      M     Electronics         1         100
# 1      M  Food&Beverages         3          75
# 2      F  Food&Beverages         4         125
# 3      M        Medicine         2          50
# 4      F      Electronix         1          80

# %%
store_data.drop(4,axis=0,inplace=True)
store_data
# Out:
#         location gender            type  quantity  total_bill  rating
# 0        Chicago      M     Electronics         1         100       2
# 1         Boston      M  Food&Beverages         3          75       4
# 2        Seattle      F  Food&Beverages         4         125       1
# 3  San Francisco      M        Medicine         2          50       3

# %%
store_data.reset_index(drop=True,inplace=True)
store_data
# Out:
#         location gender            type  quantity  total_bill  rating
# 0        Chicago      M     Electronics         1         100       2
# 1         Boston      M  Food&Beverages         3          75       4
# 2        Seattle      F  Food&Beverages         4         125       1
# 3  San Francisco      M        Medicine         2          50       3

# %% [markdown]
# Combine Data Frame

# %%
data_cust = pd.DataFrame({"customerID":['101','102','103','104'],
                        'category': ['Medium','Medium','High','Low'],
                        'first_visit': ['yes','no','yes','yes'],
                        'sales': [123,52,214,663]},index=[0,1,2,3])

data_cust_new = pd.DataFrame({"customerID":['101','103','104','105'],
                    'distance': [12,9,44,21],
                    'sales': [123,214,663,331]},index=[4,5,6,7])
print(data_cust)
print(data_cust_new)
# Out:
#   customerID category first_visit  sales
# 0        101   Medium         yes    123
# 1        102   Medium          no     52
# 2        103     High         yes    214
# 3        104      Low         yes    663
#   customerID  distance  sales
# 4        101        12    123
# 5        103         9    214
# 6        104        44    663
# 7        105        21    331

# %%
pd.concat([data_cust,data_cust_new],axis=0)
# Out:
#   customerID category first_visit  sales  distance
# 0        101   Medium         yes    123       NaN
# 1        102   Medium          no     52       NaN
# 2        103     High         yes    214       NaN
# 3        104      Low         yes    663       NaN
# 4        101      NaN         NaN    123      12.0
# 5        103      NaN         NaN    214       9.0
# 6        104      NaN         NaN    663      44.0
# 7        105      NaN         NaN    331      21.0

# %%
pd.concat([data_cust,data_cust_new],axis=1)
# Out:
#   customerID category first_visit  sales customerID  distance  sales
# 0        101   Medium         yes  123.0        NaN       NaN    NaN
# 1        102   Medium          no   52.0        NaN       NaN    NaN
# 2        103     High         yes  214.0        NaN       NaN    NaN
# 3        104      Low         yes  663.0        NaN       NaN    NaN
# 4        NaN      NaN         NaN    NaN        101      12.0  123.0
# 5        NaN      NaN         NaN    NaN        103       9.0  214.0
# 6        NaN      NaN         NaN    NaN        104      44.0  663.0
# 7        NaN      NaN         NaN    NaN        105      21.0  331.0

# %% [markdown]
# Merge and Join

# %%
pd.merge(data_cust,data_cust_new,how='outer',on='customerID')
# Out:
#   customerID category first_visit  sales_x  distance  sales_y
# 0        101   Medium         yes    123.0      12.0    123.0
# 1        102   Medium          no     52.0       NaN      NaN
# 2        103     High         yes    214.0       9.0    214.0
# 3        104      Low         yes    663.0      44.0    663.0
# 4        105      NaN         NaN      NaN      21.0    331.0

# %%
pd.merge(data_cust,data_cust_new,how='inner',on='customerID')
# Out:
#   customerID category first_visit  sales_x  distance  sales_y
# 0        101   Medium         yes      123        12      123
# 1        103     High         yes      214         9      214
# 2        104      Low         yes      663        44      663

# %%
data_quarters = pd.DataFrame({'Q1': [101,102,103],'Q2':[201,202,203]},index=['I0','I1','I2'])
data_quarters_new = pd.DataFrame({'Q3': [301,302,303],'Q4':[401,402,403]},index=['I0','I2','I3'])
print(data_quarters)
print(data_quarters_new)
# Out:
#      Q1   Q2
# I0  101  201
# I1  102  202
# I2  103  203
#      Q3   Q4
# I0  301  401
# I2  302  402
# I3  303  403

# %%
data_quarters.join(data_quarters_new,how='outer')
# Out:
#        Q1     Q2     Q3     Q4
# I0  101.0  201.0  301.0  401.0
# I1  102.0  202.0    NaN    NaN
# I2  103.0  203.0  302.0  402.0
# I3    NaN    NaN  303.0  403.0

# %%
df = pd.read_csv('StockData_1.csv')
df
# Out:
#      stock        date    price
# 0     AAPL  08-02-2013  67.8542
# 1     AAPL  11-02-2013  68.5614
# 2     AAPL  12-02-2013  66.8428
# 3     AAPL  13-02-2013  66.7156
# 4     AAPL  14-02-2013  66.6556
# ...    ...         ...      ...
# 5031   ZTS  01-02-2018  77.8200
# 5032   ZTS  02-02-2018  76.7800
# 5033   ZTS  05-02-2018  73.8300
# 5034   ZTS  06-02-2018  73.2700
# 5035   ZTS  07-02-2018  73.8600
#
# [5036 rows x 3 columns]

# %%
df.head()
# Out:
#   stock        date    price
# 0  AAPL  08-02-2013  67.8542
# 1  AAPL  11-02-2013  68.5614
# 2  AAPL  12-02-2013  66.8428
# 3  AAPL  13-02-2013  66.7156
# 4  AAPL  14-02-2013  66.6556

# %%
df.tail()
# Out:
#      stock        date  price
# 5031   ZTS  01-02-2018  77.82
# 5032   ZTS  02-02-2018  76.78
# 5033   ZTS  05-02-2018  73.83
# 5034   ZTS  06-02-2018  73.27
# 5035   ZTS  07-02-2018  73.86

# %%
df.shape
# Out:
# (5036, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5036 entries, 0 to 5035
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   stock   5036 non-null   object
#  1   date    5036 non-null   object
#  2   price   5036 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 118.2+ KB

# %%
df['stock'].value_counts(normalize=True)
# Out:
# stock
# AAPL    0.25
# SNI     0.25
# TJX     0.25
# ZTS     0.25
# Name: proportion, dtype: float64

# %%
df['price'].mean()
# Out:
# 73.05702966640192

# %%
df['price'].median()
# Out:
# 69.08500000000001

# %%
df['price'].mode()[0]
# Out:
# 74.59

# %% [markdown]
# Group By

# %%
df.groupby(['stock'])['price'].mean()
# Out:
# stock
# AAPL    109.066698
# SNI      71.319206
# TJX      66.743566
# ZTS      45.098648
# Name: price, dtype: float64

# %% [markdown]
# Apply function

# %%
def profit(s):
  return s * 10

# %%
df['new_price'] = df['price'].apply(profit)
df
# Out:
#      stock        date    price  new_price
# 0     AAPL  08-02-2013  67.8542    678.542
# 1     AAPL  11-02-2013  68.5614    685.614
# 2     AAPL  12-02-2013  66.8428    668.428
# 3     AAPL  13-02-2013  66.7156    667.156
# 4     AAPL  14-02-2013  66.6556    666.556
# ...    ...         ...      ...        ...
# 5031   ZTS  01-02-2018  77.8200    778.200
# 5032   ZTS  02-02-2018  76.7800    767.800
# 5033   ZTS  05-02-2018  73.8300    738.300
# 5034   ZTS  06-02-2018  73.2700    732.700
# 5035   ZTS  07-02-2018  73.8600    738.600
#
# [5036 rows x 4 columns]

# %%
df.sort_values('price',ascending=False)
# Out:
#      stock        date   price  new_price
# 1244  AAPL  18-01-2018  179.26     1792.6
# 1243  AAPL  17-01-2018  179.10     1791.0
# 1245  AAPL  19-01-2018  178.46     1784.6
# 1241  AAPL  12-01-2018  177.09     1770.9
# 1247  AAPL  23-01-2018  177.04     1770.4
# ...    ...         ...     ...        ...
# 4076   ZTS  17-04-2014   28.60      286.0
# 4074   ZTS  15-04-2014   28.55      285.5
# 4075   ZTS  16-04-2014   28.53      285.3
# 4073   ZTS  14-04-2014   28.48      284.8
# 4072   ZTS  11-04-2014   28.40      284.0
#
# [5036 rows x 4 columns]

# %% [markdown]
# Datetime

# %%
df['date']  = pd.to_datetime(df['date'],dayfirst=True)
df
# Out:
#      stock       date    price  new_price
# 0     AAPL 2013-02-08  67.8542    678.542
# 1     AAPL 2013-02-11  68.5614    685.614
# 2     AAPL 2013-02-12  66.8428    668.428
# 3     AAPL 2013-02-13  66.7156    667.156
# 4     AAPL 2013-02-14  66.6556    666.556
# ...    ...        ...      ...        ...
# 5031   ZTS 2018-02-01  77.8200    778.200
# 5032   ZTS 2018-02-02  76.7800    767.800
# 5033   ZTS 2018-02-05  73.8300    738.300
# 5034   ZTS 2018-02-06  73.2700    732.700
# 5035   ZTS 2018-02-07  73.8600    738.600
#
# [5036 rows x 4 columns]
